# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

# %%
sim_yr = 20

# %%
origdir = "/glade/u/home/bbuchovecky/projects/cpl_ppe_co2/hist/code/02_set-up-ensemble"
pertdir = "/glade/u/home/bbuchovecky/projects/cpl_ppe_co2/pert"

oaat_minimal = pd.read_csv(f"{pertdir}/coupPPE_OAAT.csv", names=["member", "param", "minmax"])
oaat_verbose = pd.read_csv(f"{origdir}/coupPPE-hist_params.csv")
oaat_verbose = oaat_verbose[["name", "loc", "flag", "min", "max", "def", "pft_mins", "pft_maxs"]]
clm5_params = pd.read_csv(f"{origdir}/clm5_paramranges.csv")

# %%
oaat_minimal
# Out:
#               member                         param minmax
# 0   coupPPE-hist.001                         dleaf    min
# 1   coupPPE-hist.002                         dleaf    max
# 2   coupPPE-hist.003                         d_max    min
# 3   coupPPE-hist.004                         d_max    max
# 4   coupPPE-hist.005  maximum_leaf_wetted_fraction    min
# 5   coupPPE-hist.006  maximum_leaf_wetted_fraction    max
# 6   coupPPE-hist.007                           fff    min
# 7   coupPPE-hist.008                           fff    max
# 8   coupPPE-hist.009                   medlynslope    min
# 9   coupPPE-hist.010                   medlynslope    max
# 10  coupPPE-hist.011               medlynintercept    min
# 11  coupPPE-hist.012               medlynintercept    max
# 12  coupPPE-hist.013                        Jmaxb0    min
# 13  coupPPE-hist.014                        Jmaxb0    max
# 14  coupPPE-hist.015                          kmax    min
# ...

# %%
oaat_verbose
# Out:
#                             name loc       flag        min         max  \
# 0                          dleaf   P        NaN        pft         pft
# 1                          d_max   S        NaN         10          60
# 2   maximum_leaf_wetted_fraction   N        NaN       0.01         0.5
# 3                            fff   S        NaN       0.02           5
# 4                    medlynslope   P        NaN        pft         pft
# 5                medlynintercept   P        NaN          1       12500
# 6                         Jmaxb0   S        NaN       0.01        0.05
# 7                           kmax   P        NaN        pft         pft
# 8                          psi50   P        NaN  30percent   30percent
# 9                 FUN_fracfixers   P        NaN        0.1         0.5
# 10                     kc_nonmyc   P        KCN  90percent  900percent
# 11                     kn_nonmyc   P        KCN  90percent  900percent
# ...

# %%
a = [1, 2, 3]
b = [1, 5, 6, 7]

a.isin(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 4
#       1 a = [1, 2, 3]
#       2 b = [1, 5, 6, 7]
# ----> 4 a.isin(b)
#
# AttributeError: 'list' object has no attribute 'isin'
