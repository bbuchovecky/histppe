# %%
Itp = 660/24  # sim_yr / hr
Ftp = 18/24   # sim_yr / hr
buff = 0.20

sim_yr = 50

Iwallt = sim_yr / Itp * (1 + buff)
Fwallt = sim_yr / Ftp * (1 + buff)

print(f"sim_yr = {sim_yr}")
print(f"I_wallt = {Iwallt//1:0.0f}:{Iwallt%1 * 60:0.0f}")
print(f"F_wallt = {Fwallt//1:0.0f}:{Fwallt%1 * 60:0.0f}")
# Out:
# sim_yr = 50
# I_wallt = 2:11
# F_wallt = 80:0
